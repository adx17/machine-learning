# %% [markdown]
# <a href="https://colab.research.google.com/github/adx17/machine-learning/blob/main/Regression_using_regularisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**REGURALIZATION**

# %% [markdown]
# ##I**MPORTING MODULES**

# %%
import numpy as np
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score,mean_squared_error
import matplotlib.pyplot as plt

# %% [markdown]
# ##**CREATING DATASETS**

# %%
X = np.array([[12],[23],[34],[45],[56],[67],[78],[89],[123],[134]])
Y= np.array([240,1135,2568,4521,7865,9236,11932,14589,19856,23145])

# %% [markdown]
# ##**TRAINING THE MODEL**

# %%
lr=RidgeCV()
poly=PolynomialFeatures(degree=3)
x=poly.fit_transform(X)
lr.fit(x,Y)
# Out:
# RidgeCV()

# %% [markdown]
# ##**PREDICTING OUTPUT**

# %%
y_pred=lr.predict(x)

# %% [markdown]
# ##**EVALUATING THE MODEL**

# %%
R2=r2_score(y_pred,Y)
meansq=mean_squared_error(y_pred,Y)

# %% [markdown]
# ##**PLOTTING THE GRAPH**

# %%
plt.scatter(X,Y,label="Data points")
plt.plot(X,y_pred,label="Regression line",c="r")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.grid()
plt.title("Regression using regularisation")
# Out:
# Text(0.5, 1.0, 'Regression using regularisation')
